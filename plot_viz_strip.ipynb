# %% [markdown]
# ## Plot 1D plots interactively
# (eg strip tool data)

# %%
import tifffile as tif
import sys
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy.ndimage.measurements import center_of_mass as com
from scipy.optimize import curve_fit
import os
from scipy.signal import detrend
import scipy.io as sio
from tqdm import tqdm
import math

from mda import *

# %%
# %matplotlib notebook

#Needs to follow inline magick command
import matplotlib
plt.style.use('seaborn-white')
matplotlib.rc('font',family='Times New Roman')
matplotlib.rcParams['font.size'] = 20
plt.rcParams['image.cmap'] = 'viridis'

# %%
data=np.loadtxt('/CNMshare/savedata/2019R1/20190409/cool_down1.txt', skiprows=1, usecols=(2,3,4,5))
#scan_number=160
#path='/CNMshare/savedata/2019R1/20190409/mda/26idbSOFT_%04d'  %scan_number #Scan path
#channel=20
#data=readMDA(path, showHelp=0)

# %%
#fig, ax1 = plt.subplots()
#ax1.plot(data[:,2])
#d=data[1].d[channel-1].data
#ax1.plot((d))
#plt.grid()
#ax2 = ax1.twinx()
#ax2.plot(data[:,5], 'r-')

#fig, ax1 = plt.subplots()
#ax1.plot(data[:,2])
#d=data[1].d[channel-1].data
#ax1.semilogy((d))
#plt.grid()

# %%
fig, ax1 = plt.subplots()
ax1.plot(data[:,0])
ax1.plot(data[:,1])
ax1.plot(data[:,2])
ax1.plot(data[:,3])
plt.grid()
plt.ylabel('Temperature')
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
# Text(0, 0.5, 'Temperature')
